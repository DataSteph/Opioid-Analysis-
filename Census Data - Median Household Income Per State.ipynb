# %%
#import dependencies

from census import Census
import pandas as pd
import numpy as np

#Census API Key
from localenv import api_key
c06 = Census(api_key, year= 2006)
c07 = Census(api_key, year= 2007)
c08 = Census(api_key, year= 2008)
c09 = Census(api_key, year= 2009)
c10 = Census(api_key, year= 2010)
c11 = Census(api_key, year= 2011)
c12 = Census(api_key, year= 2012)
c13 = Census(api_key, year= 2013)
c14 = Census(api_key, year= 2014)
c15 = Census(api_key, year= 2015)
c16 = Census(api_key, year= 2016)

# %%
# white alone , black alone , asian alone , indian alone
bw_09 = c09.acs5.get(("NAME",
                      "B02001_002E",
                      "B02001_003E",
                     "B02001_005E",
                     "B02001_004E"),{'for':'state'})
bw_10 = c10.acs5.get(("NAME",
                      "B02001_002E",
                      "B02001_003E",
                     "B02001_005E",
                     "B02001_004E"),{'for':'state'})
bw_11 = c11.acs5.get(("NAME","B02001_002E",
                      "B02001_003E",
                     "B02001_005E",
                     "B02001_004E"),{'for':'state'})
bw_12 = c12.acs5.get(("NAME","B02001_002E",
                      "B02001_003E",
                     "B02001_005E",
                     "B02001_004E"),{'for':'state'})
bw_13 = c13.acs5.get(("NAME","B02001_002E",
                      "B02001_003E",
                     "B02001_005E",
                     "B02001_004E"),{'for':'state'})
bw_14 = c14.acs5.get(("NAME","B02001_002E",
                     "B02001_003E",
                     "B02001_005E",
                     "B02001_004E"),{'for':'state'})
bw_15 = c15.acs5.get(("NAME","B02001_002E",
                      "B02001_003E",
                     "B02001_005E",
                     "B02001_004E"),{'for':'state'})
bw_16 = c16.acs5.get(("NAME","B02001_002E",
                      "B02001_003E",
                     "B02001_005E",
                     "B02001_004E"),{'for':'state'})

# %%
len(bw_16)
# Out:
# 52

# %%
# turn into dataframe

bw_09 = pd.DataFrame(bw_09)
bw_09["Year"] = "2009"
bw_10 = pd.DataFrame(bw_10)
bw_10["Year"] = "2010"
bw_11 = pd.DataFrame(bw_11)
bw_11["Year"] = "2011"
bw_12 = pd.DataFrame(bw_12)
bw_12["Year"] = "2012"
bw_13 = pd.DataFrame(bw_13)
bw_13["Year"] = "2013"
bw_14 = pd.DataFrame(bw_14)
bw_14["Year"] = "2014"
bw_15 = pd.DataFrame(bw_15)
bw_15["Year"] = "2015"
bw_16 = pd.DataFrame(bw_16)
bw_16["Year"] = "2016"
z = pd.merge(bw_09, bw_10, how = "outer")
zz = pd.merge(z , bw_11 , how = "outer")
zzz = pd.merge(zz , bw_12 , how = "outer")
y = pd.merge( zzz, bw_13, how = "outer")
yy = pd.merge( y, bw_14, how = "outer")
yyy =  pd.merge( yy, bw_15, how = "outer")
bw_df = pd.merge( yyy, bw_16, how="outer")

# %%
bw_df= bw_df[bw_df.NAME != "Puerto Rico"]
bw_df = bw_df.rename(columns={ "B02001_002E":"White",
                      "B02001_003E": "Black/African American",
                      "B02001_004E": "American Indian/Alaskan Native",
                      "B02001_005E":"Asian"
    
})

bw_df=bw_df[["White","Black/African American","American Indian/Alaskan Native","Asian","NAME","Year"]]
bw_df.head()
# Out:
#         White  Black/African American  American Indian/Alaskan Native  \
# 0    467650.0                 25161.0                         91939.0
# 1   3256941.0               1209938.0                         22969.0
# 2   2228798.0                439355.0                         19233.0
# 3   4906936.0                227282.0                        284265.0
# 4  22258042.0               2249404.0                        283031.0
#
#        Asian        NAME  Year
# 0    31878.0      Alaska  2009
# 1    46655.0     Alabama  2009
# 2    31120.0    Arkansas  2009
# 3   153301.0     Arizona  2009
# 4  4473292.0  California  2009

# %%
#export to csv the population data

bw_df.to_csv("race_population.csv",index=False)

# %%
#getting data from https://www.census.gov/data/developers/data-sets/acs-5year.html

# Run Census Search to retrieve data on each state FIPS code

'''income per household, income per capita, poverty, population'''

# census_data06 = c06.acs5.get(("NAME",
#                           "B19013_001E",
#                           "B19301_001E",
#                           "B17001_002E"), {'for':'state'})

# census_data07 = c07.acs5.get(("NAME",
#                           "B19013_001E",
#                           "B19301_001E",
#                           "B17001_002E"), {'for':'state'})


# census_data08 = c08.acs5.get(("NAME",
#                           "B19013_001E",
#                           "B19301_001E",
#                           "B17001_002E"), {'for':'state'})

census_data09 = c09.acs5.get(("NAME",
                          "B19013_001E",
                          "B19301_001E",
                          "B17001_002E", 
                              "B01003_001E"), {'for':'state'})

census_data10 = c10.acs5.get(("NAME",
                          "B19013_001E",
                          "B19301_001E",
                          "B17001_002E",
                              "B01003_001E"), {'for':'state'})

census_data11 = c11.acs5.get(("NAME",
                          "B19013_001E",
                          "B19301_001E",
                          "B17001_002E",
                             "B01003_001E"), {'for':'state'})

census_data12 = c12.acs5.get(("NAME",
                          "B19013_001E",
                          "B19301_001E",
                          "B17001_002E",
                             "B01003_001E"), {'for':'state'})

census_data13 = c13.acs5.get(("NAME",
                          "B19013_001E",
                          "B19301_001E",
                          "B17001_002E",
                             "B01003_001E"), {'for':'state'})

census_data14 = c14.acs5.get(("NAME",
                          "B19013_001E",
                          "B19301_001E",
                          "B17001_002E",
                             "B01003_001E"), {'for':'state'})

census_data15 = c15.acs5.get(("NAME",
                          "B19013_001E",
                          "B19301_001E",
                          "B17001_002E",
                             "B01003_001E"), {'for':'state'})

census_data16 = c16.acs5.get(("NAME",
                          "B19013_001E",
                          "B19301_001E",
                          "B17001_002E",
                             "B01003_001E"), {'for':'state'})

# %%
census_09_df = pd.DataFrame(census_data09)
census_09_df["Year"] = 2009
census_10_df = pd.DataFrame(census_data10)
census_10_df["Year"] = 2010
census_11_df = pd.DataFrame(census_data11)
census_11_df["Year"] = 2011
census_12_df = pd.DataFrame(census_data12)
census_12_df["Year"] = 2012
census_13_df = pd.DataFrame(census_data13)
census_13_df["Year"] = 2013
census_14_df = pd.DataFrame(census_data14)
census_14_df["Year"] = 2014
census_15_df = pd.DataFrame(census_data15)
census_15_df["Year"] = 2015
census_16_df = pd.DataFrame(census_data16)
census_16_df["Year"] = 2016

# %%
census_09_df
# Out:
#     B01003_001E  B17001_002E  B19013_001E  B19301_001E                  NAME  \
# 0      683142.0      64038.0      64635.0      29382.0                Alaska
# 1     4633360.0     757833.0      41216.0      22732.0               Alabama
# 2     2838143.0     488788.0      38542.0      20977.0              Arkansas
# 3     6324865.0     914040.0      50296.0      25203.0               Arizona
# 10    13  2009
# 11    15  2009
# 12    19  2009
# 13    16  2009
# 14    17  2009
# 15    18  2009
# 16    20  2009
# 17    21  2009
# 18    22  2009
# 19    25  2009
# 20    24  2009
# 21    23  2009
# 22    26  2009
# 23    27  2009
# 24    29  2009
# 25    28  2009
# 26    30  2009
# 27    37  2009
# 28    38  2009
# 29    31  2009
# 30    33  2009
# 31    34  2009
# 32    35  2009
# 33    32  2009
# 34    36  2009
# 35    39  2009
# 36    40  2009
# 37    41  2009
# 38    42  2009
# 39    72  2009
# 40    44  2009
# 41    45  2009
# 42    46  2009
# 43    47  2009
# 44    48  2009
# 45    49  2009
# 46    51  2009
# 47    50  2009
# 48    53  2009
# 49    55  2009
# 50    54  2009
# 51    56  2009

# %%
a = pd.merge(census_09_df,census_10_df,how="outer")
aa = pd.merge(a, census_11_df, how = "outer")
aaa = pd.merge( aa, census_12_df, how="outer")
b = pd.merge(aaa, census_13_df, how = "outer")
bb = pd.merge( b, census_14_df, how = "outer")
bbb = pd.merge( bb,census_15_df, how="outer")
census_y = pd.merge(bbb, census_16_df, how="outer")

# %%
census_y = census_y[["NAME","B01003_001E","B17001_002E","B19013_001E","B19301_001E","Year"]]

census_y.head()
# Out:
#          NAME  B01003_001E  B17001_002E  B19013_001E  B19301_001E  Year
# 0      Alaska     683142.0      64038.0      64635.0      29382.0  2009
# 1     Alabama    4633360.0     757833.0      41216.0      22732.0  2009
# 2    Arkansas    2838143.0     488788.0      38542.0      20977.0  2009
# 3     Arizona    6324865.0     914040.0      50296.0      25203.0  2009
# 4  California   36308527.0    4694423.0      60392.0      29020.0  2009

# %%
census_df = census_y.rename(columns = {
    "NAME":"State",
    "B01003_001E":"Population",
    "B17001_002E":"Number of Persons in Poverty",
    "B19013_001E": "Median Household Income",
    "B19301_001E": "Per Capita Income"
})
census_df.tail()
# Out:
#              State  Population  Number of Persons in Poverty  \
# 411     Washington   7073146.0                      883256.0
# 412  West Virginia   1846092.0                      318060.0
# 413      Wisconsin   5754798.0                      713472.0
# 414        Wyoming    583029.0                       65762.0
# 415    Puerto Rico   3529385.0                     1577075.0
#
#      Median Household Income  Per Capita Income  Year
# 411                  62848.0            32999.0  2016
# 412                  42644.0            24002.0  2016
# 413                  54610.0            29253.0  2016
# 414                  59143.0            30139.0  2016
# 415                  19606.0            11688.0  2016

# %%
census_df["Poverty Rate"] = (census_df["Number of Persons in Poverty"].astype(int) / census_df["Population"].astype(int) )*100

# %%
census_df.head()
# Out:
#         State  Population  Number of Persons in Poverty  \
# 0      Alaska    683142.0                       64038.0
# 1     Alabama   4633360.0                      757833.0
# 2    Arkansas   2838143.0                      488788.0
# 3     Arizona   6324865.0                      914040.0
# 4  California  36308527.0                     4694423.0
#
#    Median Household Income  Per Capita Income  Year  Poverty Rate
# 0                  64635.0            29382.0  2009      9.374039
# 1                  41216.0            22732.0  2009     16.356014
# 2                  38542.0            20977.0  2009     17.222106
# 3                  50296.0            25203.0  2009     14.451534
# 4                  60392.0            29020.0  2009     12.929258

# %%
#convert to csv 

census_income = census_df.to_csv("census_income.csv",index=False)
